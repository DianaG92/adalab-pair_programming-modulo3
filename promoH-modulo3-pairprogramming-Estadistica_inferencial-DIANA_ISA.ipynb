# %% [markdown]
# ## Pair Programming Estadística Inferencial

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stats
from scipy.stats import shapiro, poisson, chisquare, expon, kstest

pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("world-data-2023-leccion06.csv", index_col=0)
df.head()
# Out:
#        country  density abbreviation  agricultural_land   land_area  \
# 0  Afghanistan     60.0           AF               58.1      652.23
# 1      Albania    105.0           AL               43.1       28.75
# 2      Algeria     18.0           DZ               17.4  2381741.00
# 3      Andorra    164.0           AD               40.0      468.00
# 4       Angola     26.0           AO               47.5  1246700.00
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0         323.000000       32.49          93.0              Kabul
# 1           9.000000       11.78         355.0             Tirana
# 2         317.000000       24.28         213.0            Algiers
# 3       58627.064327        7.20         376.0   Andorra la Vella
# 4         117.000000       40.73         244.0             Luanda
#
#    co2-emissions       cpi  cpi_change currency-code  fertility_rate  \
# 0           8.67  149.9000    2.300000           AFN            4.47
# 1           4.54  119.0500    1.400000           ALL            1.62
# 2         150.01  151.3600    2.000000           DZD            3.02
# 3         469.00  144.1936    6.722346           EUR            1.27
# 4          34.69  261.7300   17.100000           AOA            5.52
#
#    forested_area  gasoline_price  gross_primary_education_enrollment  \
# 0            2.1            0.70                               104.0
# 1           28.1            1.36                               107.0
# 2            0.8            0.28                               109.9
# 3           34.0            1.51                               106.4
# 4           46.3            0.97                               113.5
#
#    gross_tertiary_education_enrollment  infant_mortality      largest_city  \
# 0                             9.700000              47.9             Kabul
# 1                            55.000000               7.8            Tirana
# 2                            51.400000              20.1           Algiers
# 3                            37.963388               2.7  Andorra la Vella
# 4                             9.300000              51.6            Luanda
#
#    life_expectancy  maternal_mortality_ratio  minimum_wage official_language  \
# 0        64.500000                638.000000          0.43            Pashto
# 1        78.500000                 15.000000          1.12          Albanian
# 2        76.700000                112.000000          0.95            Arabic
# 3        72.279679                160.392265          6.63           Catalan
# 4        60.800000                241.000000          0.71        Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand   population  \
# 0                              78.4                     0.28  38041754.00
# 1                              56.9                     1.20   2854191.00
# 2                              28.1                     1.72  43053054.00
# 3                              36.4                     3.33        77.14
# 4                              33.4                     0.21  31825295.00
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                 48.90     9.300000       71.400000
# 1                                 55.70    18.600000       36.600000
# 2                                 41.20    37.200000       66.100000
# 3                                 62.45    16.573964       40.822404
# 4                                 77.50     9.200000       49.100000
#
#    unemployment_rate  urban_population continent
# 0          11.120000        9797273.00      Asia
# 1          12.330000        1747593.00    Europe
# 2          11.700000       31510100.00    Africa
# 3           6.886364             67.87    Europe
# 4           6.890000       21061025.00    Africa

# %% [markdown]
# 1. Igual que en los ejercicios de la clase invertida, evalúa si las siguientes afirmaciones corresponden a una distribución exponencial o poisson.
#
# - ¿El tiempo que transcurre entre la llegada de autobuses a una parada sigue una distribución exponencial o de Poisson?

# %% [markdown]
#     - En este caso se asemeja más a una distribución exponencial, ya que esta es adecuada para modelar el tiempo entre eventos (el tiempo que pasa entre la llegada de autobuses a una parada) que tienen lugar de manera independiente.

# %% [markdown]
# - ¿El tiempo que transcurre entre la llegada de solicitudes de servicio en un restaurante sigue una distribución exponencial o de Poisson?

# %% [markdown]
#     - En este caso se asemeja más a una distribución exponencial, ya que esta es adecuada para modelar el tiempo entre eventos (el tiempo que transcurre entre la llegada de solicitudes de servicio en un restaurante) que tienen lugar de manera independiente.

# %% [markdown]
# - ¿El tiempo que transcurre entre la llegada de taxis en una parada sigue una distribución exponencial o de Poisson?

# %% [markdown]
#     - En este caso se asemeja más a una distribución exponencial, ya que esta es adecuada para modelar el tiempo entre eventos (el tiempo que pasa entre la llegada de taxis en una parada) que tienen lugar de manera independiente.

# %% [markdown]
# - ¿El número de errores de ortografía en un libro de texto sigue una distribución exponencial o de Poisson?

# %% [markdown]
#     - Pensaremos en una distribución de Poisson, que se usa comúnmente para modelar el número de eventos que suceden en un intervalo de tiempo específico cuando estos eventos son raros, como ocurre en esta situación, donde queremos contar el número de errores de ortografía en un libro de texto.

# %% [markdown]
# 2. Ejercicios intervalo de confianza. Al igual que en el caso del ejercicio de la clase invertida, piensa un motivo por el que sería interesante calcular estos intervalos de confianza para la extracción de insights.
#
# - Intervalo de Confianza para la Esperanza de Vida
#
#     Contexto: Trabajas en una organización de salud global y deseas estimar el intervalo de confianza al 95% para la esperanza de vida promedio de cada continente.
#
#     Nota: Cuidado porque puede que os salgan algunos nulos, genera un código para que no salgan nulos en los intervalos de confianza.

# %%
media_vida = df.groupby("continent")["life_expectancy"].mean()

error_vida = df.groupby("continent")["life_expectancy"].sem()

nivel_confianza_vida = 0.95

grados_libertad_vida = df.groupby("continent")["life_expectancy"].count() - 1

valor_critico_vida = grados_libertad_vida.apply(lambda df: stats.t.ppf((1 + nivel_confianza_vida) / 2, df))

limite_inferior_vida = media_vida - valor_critico_vida * error_vida
limite_superior_vida = media_vida + valor_critico_vida * error_vida

margen_error = error_vida * valor_critico_vida

margen_error = error_vida * valor_critico_vida

print("Intervalo de Confianza para la Esperanza de Vida por Continente:")
for continente in media_vida.index:
    print(f"Continente: {continente}")
    print(f"Media Muestral: {media_vida[continente]:.2f}")
    print(f"Error Estándar: {error_vida[continente]:.2f}")
    print(f"Nivel de Confianza: {nivel_confianza_vida}")
    print(f"Valor Crítico: {valor_critico_vida[continente]:.2f}")
    print(f"Intervalo de Confianza: ({limite_inferior_vida[continente]:.2f}, {limite_superior_vida[continente]:.2f})")
    print(f"Margen de Error: {margen_error[continente]:.2f}\n")
# Out:
# Intervalo de Confianza para la Esperanza de Vida por Continente:
# Continente: Africa
# Media Muestral: 64.00
# Error Estándar: 0.82
# Nivel de Confianza: 0.95
# Valor Crítico: 2.01
# Intervalo de Confianza: (62.35, 65.66)
# Margen de Error: 1.65
#
# Continente: Asia
# Media Muestral: 73.97
# Error Estándar: 0.68
# Nivel de Confianza: 0.95
# Valor Crítico: 2.01
# Intervalo de Confianza: (72.59, 75.34)
# Margen de Error: 1.37
#
# Continente: Europe
# Media Muestral: 78.70
# Error Estándar: 0.61
# Nivel de Confianza: 0.95
# Valor Crítico: 2.02
# Intervalo de Confianza: (77.48, 79.93)
# Margen de Error: 1.22
#
# Continente: North America
# Media Muestral: 75.11
# Error Estándar: 0.77
# Nivel de Confianza: 0.95
# Valor Crítico: 2.07
# Intervalo de Confianza: (73.52, 76.71)
# Margen de Error: 1.60
#
# Continente: Oceania
# Media Muestral: 71.29
# Error Estándar: 1.45
# Nivel de Confianza: 0.95
# Valor Crítico: 2.16
# Intervalo de Confianza: (68.16, 74.42)
# Margen de Error: 3.13
#
# Continente: South America
# Media Muestral: 74.93
# Error Estándar: 0.90
# Nivel de Confianza: 0.95
# Valor Crítico: 2.20
# Intervalo de Confianza: (72.95, 76.92)
# Margen de Error: 1.99

# %% [markdown]
# - Intervalo de Confianza para el PIB
#
#     Contexto: Eres una economista y quieres calcular el intervalo de confianza al 90% para el Producto Interno Bruto (PIB) de los continentes.

# %%
# Realizamos el ejercicio usando la columna "cpi" porque no tenemos la columna que nos indica el enunciado
media_cpi = df.groupby("continent")["cpi"].mean()

error_cpi = df.groupby("continent")["cpi"].sem()

nivel_confianza_cpi = 0.90

grados_libertad_cpi = df.groupby("continent")["cpi"].count() - 1

valor_critico_cpi = grados_libertad_cpi.apply(lambda df: stats.t.ppf((1 + nivel_confianza_cpi) / 2, df))

limite_inferior_cpi = media_cpi - valor_critico_cpi * error_cpi
limite_superior_cpi = media_cpi + valor_critico_cpi * error_cpi

margen_error = error_cpi * valor_critico_cpi

print("Intervalo de Confianza para el CPI por Continente:")
for continente in media_cpi.index:
    print(f"Continente: {continente}")
    print(f"Media Muestral: {media_cpi[continente]:.2f}")
    print(f"Error Estándar: {error_cpi[continente]:.2f}")
    print(f"Nivel de Confianza: {nivel_confianza_cpi}")
    print(f"Valor Crítico: {valor_critico_cpi[continente]:.2f}")
    print(f"Intervalo de Confianza: ({limite_inferior_cpi[continente]:.2f}, {limite_superior_cpi[continente]:.2f})")
    print(f"Margen de Error: {margen_error[continente]:.2f}\n")
# Out:
# Intervalo de Confianza para el CPI por Continente:
# Continente: Africa
# Media Muestral: 161.33
# Error Estándar: 8.15
# Nivel de Confianza: 0.9
# Valor Crítico: 1.67
# Intervalo de Confianza: (147.68, 174.97)
# Margen de Error: 13.65
#
# Continente: Asia
# Media Muestral: 149.49
# Error Estándar: 9.49
# Nivel de Confianza: 0.9
# Valor Crítico: 1.68
# Intervalo de Confianza: (133.58, 165.41)
# Margen de Error: 15.92
#
# Continente: Europe
# Media Muestral: 125.40
# Error Estándar: 4.43
# Nivel de Confianza: 0.9
# Valor Crítico: 1.68
# Intervalo de Confianza: (117.95, 132.85)
# Margen de Error: 7.45
#
# Continente: North America
# Media Muestral: 128.80
# Error Estándar: 4.46
# Nivel de Confianza: 0.9
# Valor Crítico: 1.72
# Intervalo de Confianza: (121.14, 136.46)
# Margen de Error: 7.66
#
# Continente: Oceania
# Media Muestral: 126.68
# Error Estándar: 4.25
# Nivel de Confianza: 0.9
# Valor Crítico: 1.77
# Intervalo de Confianza: (119.17, 134.20)
# Margen de Error: 7.52
#
# Continente: South America
# Media Muestral: 164.75
# Error Estándar: 15.32
# Nivel de Confianza: 0.9
# Valor Crítico: 1.80
# Intervalo de Confianza: (137.24, 192.26)
# Margen de Error: 27.51

# %% [markdown]
# ### Bonus:

# %% [markdown]
# - Intervalo de Confianza para la Tasa de Natalidad
#
#     Contexto: Trabajas en una agencia gubernamental que se ocupa de cuestiones demográficas y deseas determinar el intervalo de confianza al 99% para la tasa de natalidad promedio en Asia.

# %%
# Creamos una función general que nos sirva para resolver cada uno de los ejercicios 
def intervalo_confianza(dataframe, columna, nivel_confianza = float):
    
    # Calculamos la media y el error estándar de la muestra
    media = dataframe[columna].mean()
    error = stats.sem(dataframe[columna], nan_policy= "omit")

    # Calculamos los grados de libertad de la muestra
    grados_libertad = len(df[columna]) - 1

    # Calculamos el valor crítico (utilizando la distribución t de Student)
    valor_critico = stats.t.ppf((1 + nivel_confianza) / 2, df=grados_libertad)

    # Calculamos el intervalo de confianza
    limite_inferior = media - valor_critico * error
    limite_superior = media + valor_critico * error

    print(f"Intervalo de Confianza para {columna}:")
    print(f"Media Muestral: {np.round(media, 2)}")
    print(f"Error Estándar: {np.round(error, 2)}")
    print(f"Nivel de Confianza: {nivel_confianza}")
    print(f"Valor Crítico: {np.round(valor_critico, 2)}")
    print(f"Intervalo de Confianza: ({np.round(limite_inferior, 2)}, {np.round(limite_superior, 2)})")

# %%
df_asia = df[df["continent"] == "Asia"]

intervalo_confianza(df_asia, "birth_rate", 0.99)
# Out:
# Intervalo de Confianza para birth_rate:
# Media Muestral: 18.5
# Error Estándar: 0.93
# Nivel de Confianza: 0.99
# Valor Crítico: 2.6
# Intervalo de Confianza: (16.07, 20.92)

# %% [markdown]
# - Intervalo de Confianza para la Tasa de Desempleo
#
#     Contexto: Eres un analista de políticas públicas y deseas calcular el intervalo de confianza al 95% para la tasa de desempleo promedio en los países de Oceanía.

# %%
df_oceania = df[df["continent"] == "Oceania"]

intervalo_confianza(df_oceania, "unemployment_rate", 0.95)
# Out:
# Intervalo de Confianza para unemployment_rate:
# Media Muestral: 5.12
# Error Estándar: 0.64
# Nivel de Confianza: 0.95
# Valor Crítico: 1.97
# Intervalo de Confianza: (3.85, 6.39)

# %% [markdown]
# - Intervalo de Confianza para la Tasa de Impuestos
#
#     Contexto: Trabajas en un ministerio de finanzas y deseas estimar el intervalo de confianza al 90% para la tasa de impuestos promedio en los países de África.

# %%
df_africa = df[df["continent"] == "Africa"]

intervalo_confianza(df_africa, "total_tax_rate", 0.90)
# Out:
# Intervalo de Confianza para total_tax_rate:
# Media Muestral: 47.31
# Error Estándar: 3.82
# Nivel de Confianza: 0.9
# Valor Crítico: 1.65
# Intervalo de Confianza: (40.99, 53.63)
