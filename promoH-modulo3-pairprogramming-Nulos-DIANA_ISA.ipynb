# %% [markdown]
# ## Pair Programming Nulos

# %% [markdown]
# ### Ejercicios gestión de nulos

# %% [markdown]
# 1. Identificación de Valores Nulos: Identifica todas las columnas que contengan valores nulos en el DataFrame.

# %%
import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("world-data-2023-leccion05.csv")

data.head(5)
# Out:
#        country  density abbreviation  agricultural_land   land_area  \
# 0  Afghanistan     60.0           AF               58.1      652.23
# 1      Albania    105.0           AL               43.1       28.75
# 2      Algeria     18.0           DZ               17.4  2381741.00
# 3      Andorra    164.0           AD               40.0      468.00
# 4       Angola     26.0           AO               47.5  1246700.00
#
#    armed_forces_size  birth_rate  calling_code capital/major_city  \
# 0              323.0       32.49          93.0              Kabul
# 1                9.0       11.78         355.0             Tirana
# 2              317.0       24.28         213.0            Algiers
# 3                NaN        7.20         376.0   Andorra la Vella
# 4              117.0       40.73         244.0             Luanda
#
#    co2-emissions     cpi  cpi_change currency-code  fertility_rate  \
# 0           8.67  149.90         2.3           AFN            4.47
# 1           4.54  119.05         1.4           ALL            1.62
# 2         150.01  151.36         2.0           DZD            3.02
# 3         469.00     NaN         NaN           EUR            1.27
# 4          34.69  261.73        17.1           AOA            5.52
#
#    forested_area gasoline_price  gdp  gross_primary_education_enrollment  \
# 0            2.1         $0.70   NaN                               104.0
# 1           28.1         $1.36   NaN                               107.0
# 2            0.8         $0.28   NaN                               109.9
# 3           34.0         $1.51   NaN                               106.4
# 4           46.3         $0.97   NaN                               113.5
#
#    gross_tertiary_education_enrollment  infant_mortality      largest_city  \
# 0                                  9.7              47.9             Kabul
# 1                                 55.0               7.8            Tirana
# 2                                 51.4              20.1           Algiers
# 3                                  NaN               2.7  Andorra la Vella
# 4                                  9.3              51.6            Luanda
#
#    life_expectancy  maternal_mortality_ratio minimum_wage official_language  \
# 0             64.5                     638.0       $0.43             Pashto
# 1             78.5                      15.0       $1.12           Albanian
# 2             76.7                     112.0       $0.95             Arabic
# 3              NaN                       NaN       $6.63            Catalan
# 4             60.8                     241.0       $0.71         Portuguese
#
#    out_of_pocket_health_expenditure  physicians_per_thousand   population  \
# 0                              78.4                     0.28  38041754.00
# 1                              56.9                     1.20   2854191.00
# 2                              28.1                     1.72  43053054.00
# 3                              36.4                     3.33        77.14
# 4                              33.4                     0.21  31825295.00
#
#    population_labor_force_participation  tax_revenue  total_tax_rate  \
# 0                                  48.9          9.3            71.4
# 1                                  55.7         18.6            36.6
# 2                                  41.2         37.2            66.1
# 3                                   NaN          NaN             NaN
# 4                                  77.5          9.2            49.1
#
#    unemployment_rate  urban_population  latitud  longitud continent
# 0              11.12        9797273.00      NaN       NaN      Asia
# 1              12.33        1747593.00      NaN       NaN    Europe
# 2              11.70       31510100.00      NaN       NaN    Africa
# 3                NaN             67.87      NaN       NaN    Europe
# 4               6.89       21061025.00      NaN       NaN    Africa

# %%
# Visualizamos sólo las columnas con valores nulos
data.isnull().sum()[data.isnull().sum() > 0]
# Out:
# abbreviation                              7
# agricultural_land                         7
# land_area                                 1
# armed_forces_size                        24
# birth_rate                                6
# calling_code                              1
# capital/major_city                        3
# co2-emissions                             7
# cpi                                      20
# cpi_change                               16
# currency-code                            15
# fertility_rate                            7
# forested_area                             7
# gasoline_price                           20
# gdp                                     195
# gross_primary_education_enrollment        7
# gross_tertiary_education_enrollment      12
# infant_mortality                          6
# largest_city                              6
# life_expectancy                           8
# maternal_mortality_ratio                 14
# minimum_wage                             45
# official_language                         5
# out_of_pocket_health_expenditure          7
# physicians_per_thousand                   7
# population                                1
# population_labor_force_participation     19
# tax_revenue                              26
# total_tax_rate                           12
# unemployment_rate                        19
# urban_population                          5
# latitud                                 195
# longitud                                195
# dtype: int64

# %% [markdown]
# 2. Selección de Método de Imputación: Discute en tu compañera cuál sería la mejor estrategia para manejar los valores nulos en cada una de las columnas identificadas en el paso anterior.
#
# 3. Imputación de Valores Nulos: Implementa el método de imputación seleccionado en el paso 2 para llenar los valores nulos en las columnas.

# %%
# Columna "abbreviation": método .fillna("Unknown"), porque no sigue ningún patrón.
data["abbreviation"] = data["abbreviation"].fillna("Unknown")

# %%
# Columna "agricultural_land": utilizamos IterativeImputer para que haga una estimación en base a las relaciones de los datos completos.
imputer = IterativeImputer(max_iter=10, random_state=42)

datos_imputados = imputer.fit_transform(data[["agricultural_land"]])

data[["agricultural_land"]] = datos_imputados

# %%
# Columna "land_area": método .fillna(median()), porque no sigue ningún patrón y así, le asignamos un valor numérico.
data["land_area"] = data["land_area"].fillna(data["land_area"].median())

# %%
data.sample(5)
# Out:
#                     country  density abbreviation  agricultural_land  \
# 54                  Eritrea     35.0           ER               75.2
# 70            Guinea-Bissau     70.0           GW               58.0
# 185          United Kingdom    281.0           GB               71.7
# 21   Bosnia and Herzegovina     64.0           BA               43.1
# 84                  Jamaica    273.0           JM               41.0
#
#      land_area  armed_forces_size  birth_rate  calling_code  \
# 54      117.60              202.0       30.30         291.0
# 70       36.12                4.0       35.13         245.0
# 185     243.61              148.0       11.00          44.0
# 21       51.20               11.0        8.11         387.0
# 84       10.99                4.0       16.10        1876.0
#
#     capital/major_city  co2-emissions     cpi  cpi_change currency-code  \
# 54              Asmara         711.00     NaN         NaN           ERN
# 70              Bissau         293.00  111.65         1.4           XOF
# 185             London         379.02  119.62         1.7           GBP
# 21            Sarajevo          21.85  104.90         0.6           BAM
# 84   Kingston, Jamaica           8.22  162.47         3.9           JMD
#
#      fertility_rate  forested_area gasoline_price  gdp  \
# 54             4.06           14.9         $2.00   NaN
# 70             4.48           69.8            NaN  NaN
# 185            1.68           13.1         $1.46   NaN
# 21             1.27           42.7         $1.05   NaN
# 84             1.98           30.9         $1.11   NaN
#
#      gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 54                                 68.4                                  3.4
# 70                                118.7                                  2.6
# 185                               101.2                                 60.0
# 21                                  NaN                                 23.3
# 84                                 91.0                                 27.1
#
#      infant_mortality       largest_city  life_expectancy  \
# 54               31.3             Asmara             65.9
# 70               54.0             Bissau             58.0
# 185               3.6             London             81.3
# 21                5.0       Tuzla Canton             77.3
# 84               12.4  Kingston, Jamaica             74.4
#
#      maternal_mortality_ratio minimum_wage official_language  \
# 54                      480.0          NaN          Tigrinya
# 70                      667.0       $0.16         Portuguese
# 185                       7.0      $10.13            English
# 21                       10.0       $1.04            Bosnian
# 84                       80.0       $1.33   Jamaican English
#
#      out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 54                               52.4                     0.06   6333135.0
# 70                               37.2                     0.13   1920922.0
# 185                              14.8                     2.81  66834405.0
# 21                               28.6                     2.16   3301000.0
# 84                               23.7                     1.31   2948279.0
#
#      population_labor_force_participation  tax_revenue  total_tax_rate  \
# 54                                   78.4          NaN            83.7
# 70                                   72.0         10.3            45.5
# 185                                  62.8         25.5            30.6
# 21                                   46.4         20.4            23.7
# 84                                   66.0         26.8            35.1
#
#      unemployment_rate  urban_population  latitud  longitud      continent
# 54                5.14        1149670.00      NaN       NaN         Africa
# 70                2.47            840.92      NaN       NaN         Africa
# 185               3.85       55908316.00      NaN       NaN         Europe
# 21               18.42        1605144.00      NaN       NaN         Europe
# 84                8.00        1650594.00      NaN       NaN  North America

# %%
# Columna "armed_forces_size": utilizamos IterativeImputer para que haga una estimación en base a las relaciones de los datos completos.
imputer = IterativeImputer(max_iter=10, random_state=42)

datos_imputados = imputer.fit_transform(data[["armed_forces_size"]])

data[["armed_forces_size"]] = datos_imputados

# %%
# Columna "birth_rate": utilizamos IterativeImputer para que haga una estimación en base a las relaciones de los datos completos.
imputer = IterativeImputer(max_iter=10, random_state=42)

datos_imputados = imputer.fit_transform(data[["birth_rate"]])

data[["birth_rate"]] = datos_imputados

# %%
# Columna "calling_code":

# %% [markdown]
# 4. Informe: Añade al final de un jupyter una explicación breve que describa las columnas que tenían valores nulos, cómo decidiste imputarlos y cualquier observación adicional que consideres importante sobre el proceso de limpieza de datos.

# %%
data[data['armed_forces_size'].isnull()]
# Out:
#                               country  density abbreviation  \
# 3                             Andorra   164.00           AD
# 38                            Comoros   467.00           KM
# 48                           Dominica    96.00           DM
# 56                           Eswatini    67.00      Unknown
# 67                            Grenada   331.00           GD
# 73                       Vatican City     2.00      Unknown
# 89                           Kiribati   147.00           KI
# 98                      Liechtenstein   238.00           LI
# 107                  Marshall Islands   329.00           MH
# 111    Federated States of Micronesia   784.00           FM
# 113                            Monaco    26.34           MC
# 120                             Nauru   541.00           NR
# 128                   North Macedonia    83.00      Unknown
# 132                             Palau    39.00           PW
# 133                         Palestine   847.00      Unknown
# 145             Saint Kitts and Nevis   205.00           KN
# 146                       Saint Lucia   301.00           LC
# 147  Saint Vincent and the Grenadines   284.00           VC
# 148                             Samoa    70.00           WS
# 149                        San Marino   566.00           SM
# 159                   Solomon Islands    25.00           SB
# 176                             Tonga   147.00           TO
# 181                            Tuvalu   393.00           TV
# 189                           Vanuatu    25.00           VU
#
#      agricultural_land  land_area  armed_forces_size  birth_rate  \
# 3            40.000000    468.000                NaN        7.20
# 38           71.500000      2.230                NaN       31.88
# 48           33.300000    751.000                NaN       12.00
# 56           39.117553     17.360                NaN         NaN
# 67           23.500000    349.000                NaN       16.47
# 73           39.117553      0.000                NaN         NaN
# 89           42.000000    811.000                NaN       27.89
# 98           32.200000    160.000                NaN        9.90
# 107          63.900000    181.000                NaN       29.03
# 111          31.400000    702.000                NaN       22.82
# 113          39.117553      2.000                NaN        5.90
# 120          39.117553     21.000                NaN         NaN
# 128          39.117553     25.710                NaN         NaN
# 132          10.900000    459.000                NaN       14.00
# 133          39.117553    239.785                NaN         NaN
# 145          23.100000    261.000                NaN       12.60
# 146          17.400000    616.000                NaN       12.00
# 147          25.600000    389.000                NaN       14.24
# 148          12.400000      2.830                NaN       24.38
# 149          16.700000     61.000                NaN        6.80
# 159           3.900000     28.900                NaN       32.44
# 176          45.800000    747.000                NaN       24.30
# 181          60.000000     26.000                NaN         NaN
# 189          15.300000     12.190                NaN       29.60
#
#      calling_code     capital/major_city  co2-emissions     cpi  cpi_change  \
# 3           376.0       Andorra la Vella          469.0     NaN         NaN
# 38          269.0        Moroni, Comoros          202.0  103.62        -4.3
# 48            1.0                 Roseau          180.0  103.87         1.0
# 56          268.0                Mbabane            NaN     NaN         NaN
# 67            1.0  St. George's, Grenada          268.0  107.43         0.8
# 73          379.0           Vatican City            NaN     NaN         NaN
# 89          686.0           South Tarawa           66.0   99.55         0.6
# 98          423.0                  Vaduz           51.0     NaN         NaN
# 107         692.0                 Majuro          143.0     NaN         NaN
# 111         691.0                Palikir          143.0  112.10         0.5
# 113         377.0            Monaco City            NaN     NaN         NaN
# 120         674.0         Yaren District            NaN     NaN         NaN
# 128         389.0                 Skopje            NaN     NaN         NaN
# 132         680.0              Ngerulmud          224.0  118.17         1.3
# 133           NaN                    NaN            NaN     NaN         NaN
# 145           1.0             Basseterre          238.0  104.57        -1.0
# 146           1.0               Castries          414.0  110.13         1.9
# 147           1.0              Kingstown          220.0  109.67         2.3
# 148         685.0                   Apia          246.0  117.56         1.0
# 149         378.0     City of San Marino            NaN  110.63         1.0
# 159         677.0                Honiara          169.0  133.06         1.6
# 176         676.0               Nuku����          128.0  121.09         7.4
# 181         688.0               Funafuti           11.0     NaN         NaN
# 189         678.0              Port Vila          147.0  117.13         2.8
#
#     currency-code  fertility_rate  forested_area gasoline_price  gdp  \
# 3             EUR            1.27           34.0         $1.51   NaN
# 38            KMF            4.21           19.7            NaN  NaN
# 48            XCD            1.90           57.4            NaN  NaN
# 56            NaN             NaN            NaN            NaN  NaN
# 67            XCD            2.06           50.0         $1.12   NaN
# 73            EUR             NaN            NaN            NaN  NaN
# 89            AUD            3.57           15.0            NaN  NaN
# 98            CHF            1.44           43.1         $1.74   NaN
# 107           USD            4.05           70.2         $1.44   NaN
# 111           USD            3.05           91.9            NaN  NaN
# 113           EUR             NaN            NaN         $2.00   NaN
# 120           AUD             NaN            NaN            NaN  NaN
# 128           MKD             NaN            NaN            NaN  NaN
# 132           USD            2.21           87.6            NaN  NaN
# 133           NaN             NaN            NaN            NaN  NaN
# 145           XCD            2.11           42.3            NaN  NaN
# 146           XCD            1.44           33.2         $1.30   NaN
# 147           XCD            1.89           69.2            NaN  NaN
# 148           WST            3.88           60.4         $0.91   NaN
# 149           EUR            1.26            0.0            NaN  NaN
# 159           SBD            4.40           77.9            NaN  NaN
# 176           TOP            3.56           12.5            NaN  NaN
# 181           AUD             NaN           33.3            NaN  NaN
# 189           VUV            3.78           36.1         $1.31   NaN
#
#      gross_primary_education_enrollment  gross_tertiary_education_enrollment  \
# 3                                 106.4                                  NaN
# 38                                 99.5                                  9.0
# 48                                114.7                                  7.2
# 56                                  NaN                                  NaN
# 67                                106.9                                104.6
# 73                                  NaN                                  NaN
# 89                                101.3                                  NaN
# 98                                104.7                                 35.6
# 107                                84.7                                 23.7
# 111                                97.2                                 14.1
# 113                                 NaN                                  NaN
# 120                                 NaN                                  NaN
# 128                                 NaN                                  NaN
# 132                               112.6                                 54.7
# 133                                 NaN                                  NaN
# 145                               108.7                                 86.7
# 146                               102.6                                 14.1
# 147                               113.4                                 23.7
# 148                               110.5                                  7.6
# 149                               108.1                                 42.5
# 159                               106.2                                  NaN
# 176                               116.3                                  6.4
# 181                                86.0                                  NaN
# 189                               109.3                                  4.7
#
#      infant_mortality           largest_city  life_expectancy  \
# 3                 2.7       Andorra la Vella              NaN
# 38               51.3        Moroni, Comoros             64.1
# 48               32.9                 Roseau             76.6
# 56                NaN                Mbabane              NaN
# 67               13.7  St. George's, Grenada             72.4
# 73                NaN                    NaN              NaN
# 89               41.2           South Tarawa             68.1
# 98                NaN                 Schaan             83.0
# 107              27.4                 Majuro             65.2
# 111              25.6                Palikir             67.8
# 113               2.6            Monaco City              NaN
# 120               NaN                    NaN              NaN
# 128               NaN                 Skopje              NaN
# 132              16.6                  Koror             69.1
# 133               NaN                    NaN              NaN
# 145               9.8             Basseterre             71.3
# 146              14.9               Castries             76.1
# 147              14.8              Calliaqua             72.4
# 148              13.6                   Apia             73.2
# 149               1.7     City of San Marino             85.4
# 159              17.1                Honiara             72.8
# 176              13.4               Nuku����             70.8
# 181              20.6              Singapore              NaN
# 189              22.3              Port Vila             70.3
#
#      maternal_mortality_ratio minimum_wage  official_language  \
# 3                         NaN       $6.63             Catalan
# 38                      273.0       $0.71              French
# 48                        NaN       $1.48             English
# 56                        NaN          NaN            English
# 67                       25.0          NaN            English
# 73                        NaN          NaN            Italian
# 89                       92.0          NaN            English
# 98                        NaN          NaN             German
# 107                       NaN       $2.00         Marshallese
# 111                      88.0          NaN            English
# 113                       NaN      $11.72              French
# 120                       NaN          NaN            English
# 128                       NaN          NaN         Macedonian
# 132                       NaN       $3.00             English
# 133                       NaN          NaN             Arabic
# 145                       NaN       $3.33             English
# 146                     117.0          NaN            English
# 147                      68.0       $1.16             English
# 148                      43.0       $0.78              Samoan
# 149                       NaN          NaN            Italian
# 159                     104.0       $0.40             English
# 176                      52.0          NaN    Tongan Language
# 181                       NaN          NaN  Tuvaluan Language
# 189                      72.0       $1.56              French
#
#      out_of_pocket_health_expenditure  physicians_per_thousand  population  \
# 3                                36.4                     3.33       77.14
# 38                               74.8                     0.27      850.89
# 48                               28.4                     1.08       71.81
# 56                               11.3                      NaN  1093238.00
# 67                               57.0                     1.41      112.00
# 73                                NaN                      NaN      836.00
# 89                                0.2                     0.20      117.61
# 98                                NaN                      NaN       38.02
# 107                              10.0                     0.42       58.79
# 111                               2.5                     0.18      113.81
# 113                               6.1                     6.56       38.96
# 120                               NaN                      NaN       10.08
# 128                              35.6                      NaN  1836713.00
# 132                              21.8                     1.18       18.23
# 133                               NaN                      NaN         NaN
# 145                              56.6                     2.52       52.82
# 146                              48.4                     0.64      182.79
# 147                              21.4                     0.66      100.45
# 148                              11.5                     0.34      202.51
# 149                              18.3                     6.11       33.86
# 159                               3.3                     0.19      669.82
# 176                              10.2                     0.52      100.21
# 181                               0.7                     0.92       11.65
# 189                               8.9                     0.17      299.88
#
#      population_labor_force_participation  tax_revenue  total_tax_rate  \
# 3                                     NaN          NaN             NaN
# 38                                   43.3          NaN           219.6
# 48                                    NaN         22.1            32.6
# 56                                    NaN         28.6             NaN
# 67                                    NaN         19.4            47.8
# 73                                    NaN          NaN             NaN
# 89                                    NaN         22.0            32.7
# 98                                    NaN          NaN            21.6
# 107                                   NaN         17.8            65.9
# 111                                   NaN         25.2            60.5
# 113                                   NaN          NaN             NaN
# 120                                   NaN          NaN             NaN
# 128                                   NaN          NaN             NaN
# 132                                   NaN         21.3            76.6
# 133                                   NaN          NaN             NaN
# 145                                   NaN         18.5            49.7
# 146                                  67.1         18.2            34.7
# 147                                  65.9         25.4            37.0
# 148                                  43.7         25.5            19.3
# 149                                   NaN         18.1            36.2
# 159                                  83.8         29.5            32.0
# 176                                  59.8         22.3            27.5
# 181                                   NaN          NaN             NaN
# 189                                  69.9         17.8             8.5
#
#      unemployment_rate  urban_population  latitud  longitud      continent
# 3                  NaN             67.87      NaN       NaN         Europe
# 38                4.34            248.15      NaN       NaN         Africa
# 48                 NaN             50.83      NaN       NaN  North America
# 56                 NaN               NaN      NaN       NaN         Africa
# 67                 NaN             40.77      NaN       NaN  North America
# 73                 NaN               NaN      NaN       NaN         Europe
# 89                 NaN             64.49      NaN       NaN        Oceania
# 98                 NaN              5.46      NaN       NaN         Europe
# 107                NaN             45.51      NaN       NaN        Oceania
# 111                NaN             25.96      NaN       NaN        Oceania
# 113                NaN             38.96      NaN       NaN         Europe
# 120                NaN               NaN      NaN       NaN        Oceania
# 128                NaN               NaN      NaN       NaN         Europe
# 132                NaN             14.49      NaN       NaN        Oceania
# 133                NaN               NaN      NaN       NaN           Asia
# 145                NaN             16.27      NaN       NaN  North America
# 146              20.71             34.28      NaN       NaN  North America
# 147              18.88             58.19      NaN       NaN  North America
# 148               8.36             35.59      NaN       NaN        Oceania
# 149                NaN             32.97      NaN       NaN         Europe
# 159               0.58            162.16      NaN       NaN        Oceania
# 176               1.12             24.14      NaN       NaN        Oceania
# 181                NaN              7.36      NaN       NaN        Oceania
# 189               4.39             76.15      NaN       NaN        Oceania
